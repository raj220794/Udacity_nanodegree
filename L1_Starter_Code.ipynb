# %% [markdown]
# ## Load Data from CSVs

# %%
import unicodecsv

## Longer version of code (replaced with shorter, equivalent version below)

# enrollments = []
# f = open('enrollments.csv', 'rb')
# reader = unicodecsv.DictReader(f)
# for row in reader:
#     enrollments.append(row)
# f.close()
def read_csv(filename):
    with open(filename,'rb') as f:
        reader=unicodecsv.DictReader(f)
        return list(reader)
with open('enrollments.csv', 'rb') as f:
    reader = unicodecsv.DictReader(f)
    enrollments = list(reader)

# %%
#####################################
#                 1                 #
#####################################

## Read in the data from daily_engagement.csv and project_submissions.csv 
## and store the results in the below variables.
## Then look at the first row of each table.

daily_engagement = read_csv("./daily_engagement.csv")
project_submissions = read_csv("./project_submissions.csv")

# %% [markdown]
# ## Fixing Data Types

# %%
from datetime import datetime as dt

# Takes a date as a string, and returns a Python datetime object. 
# If there is no date given, returns None
def parse_date(date):
    if date == '':
        return None
    else:
        return dt.strptime(date, '%Y-%m-%d')
    
# Takes a string which is either an empty string or represents an integer,
# and returns an int or None.
def parse_maybe_int(i):
    if i == '':
        return None
    else:
        return int(i)

# Clean up the data types in the enrollments table
for enrollment in enrollments:
    enrollment['cancel_date'] = parse_date(enrollment['cancel_date'])
    enrollment['days_to_cancel'] = parse_maybe_int(enrollment['days_to_cancel'])
    enrollment['is_canceled'] = enrollment['is_canceled'] == 'True'
    enrollment['is_udacity'] = enrollment['is_udacity'] == 'True'
    enrollment['join_date'] = parse_date(enrollment['join_date'])
    
enrollments[0]
# Out:
# OrderedDict([('account_key', '448'),
#              ('status', 'canceled'),
#              ('join_date', datetime.datetime(2014, 11, 10, 0, 0)),
#              ('cancel_date', datetime.datetime(2015, 1, 14, 0, 0)),
#              ('days_to_cancel', 65),
#              ('is_udacity', True),
#              ('is_canceled', True)])

# %%
# Clean up the data types in the engagement table
for engagement_record in daily_engagement:
    
    engagement_record['lessons_completed'] = int(float(engagement_record['lessons_completed']))
    engagement_record['num_courses_visited'] = int(float(engagement_record['num_courses_visited']))
    engagement_record['projects_completed'] = int(float(engagement_record['projects_completed']))
    engagement_record['total_minutes_visited'] = float(engagement_record['total_minutes_visited'])
    engagement_record['utc_date'] = parse_date(engagement_record['utc_date'])
    
daily_engagement[0]
# Out:
# OrderedDict([('acct', '0'),
#              ('utc_date', datetime.datetime(2015, 1, 9, 0, 0)),
#              ('num_courses_visited', 1),
#              ('total_minutes_visited', 11.6793745),
#              ('lessons_completed', 0),
#              ('projects_completed', 0)])

# %%
# Clean up the data types in the submissions table
for submission in project_submissions:
    submission['completion_date'] = parse_date(submission['completion_date'])
    submission['creation_date'] = parse_date(submission['creation_date'])

project_submissions[0]
# Out:
# OrderedDict([('creation_date', datetime.datetime(2015, 1, 14, 0, 0)),
#              ('completion_date', datetime.datetime(2015, 1, 16, 0, 0)),
#              ('assigned_rating', 'UNGRADED'),
#              ('account_key', '256'),
#              ('lesson_key', '3176718735'),
#              ('processing_state', 'EVALUATED')])

# %% [markdown]
# ## Investigating the Data

# %%
#####################################
#                 2                 #
#####################################
def unique(table,column):
    unique_acc=set()
    for row in table:
        unique_acc.add(row[column])
    return(unique_acc)
## Find the total number of rows and the number of unique students (account keys)
## in each table.
enrollment_unique=unique(enrollments,'account_key')
engage_unique=unique(daily_engagement,'acct')

# %%
print(len(engage_unique))
print(len(enrollment_unique))
# Out:
# 1237
# 1302

# %% [markdown]
# ## Problems in the Data

# %%
#####################################
#                 3                 #
#####################################
for engage in daily_engagement:
    engage['account_key']=engage['acct']
    del(engage['acct'])
daily_engagement[0]['account_key']

## Rename the "acct" column in the daily_engagement table to "account_key".
# Out:
# '0'

# %% [markdown]
# ## Missing Engagement Records

# %%
#####################################
#                 4                 #
#####################################
enroll_proxy=enrollments
count=0
for enroll in enroll_proxy:
    student=enroll['account_key']
    
    if student not in engage_unique:
        print(enroll['account_key'])
        if enroll['days_to_cancel'] != 0:
            
            print(enroll['days_to_cancel'])
## Find any one student enrollments where the student is missing from the daily engagement table.
## Output that enrollment.
# Out:
# 1219
# 871
# 1218
# 654
# 654
# 654
# 964
# 817
# 1171
# 884
# 875
# 1120
# 728
# 1191
# 1304
# 59
# 1304
# 99
# 1010
# 841
# 707
# 717
# 727
# 1273
# 1238
# 1044
# 749
# 1129
# 1129
# 926
# 711
# 803
# 799
# 789
# 819
# 819
# 902
# 996
# 1213
# 733
# 1237
# 1069
# 1086
# 1190
# 914
# 914
# 968
# 1155
# 766
# 739
# 1222
# 1125
# 1025
# 750
# 889
# 737
# 878
# 981
# 1101
# None
# 1148
# 1186
# 725
# 1145
# 802
# 664
# 997
# 870
# 1284
# 1079
# 1063
# 1270
# 1291
# 1241

# %% [markdown]
# ## Checking for More Problem Records

# %%
#####################################
#                 5                 #
#####################################

## Find the number of surprising data points (enrollments missing from
## the engagement table) that remain, if any.

# %% [markdown]
# ## Tracking Down the Remaining Problems

# %%
# Create a set of the account keys for all Udacity test accounts
udacity_test_accounts = set()
for enrollment in enrollments:
    if enrollment['is_udacity']:
        udacity_test_accounts.add(enrollment['account_key'])
len(udacity_test_accounts)
# Out:
# 6

# %%
# Given some data with an account_key field, removes any records corresponding to Udacity test accounts
def remove_udacity_accounts(data):
    non_udacity_data = []
    for data_point in data:
        if data_point['account_key'] not in udacity_test_accounts:
            non_udacity_data.append(data_point)
    return non_udacity_data

# %%
# Remove Udacity test accounts from all three tables
non_udacity_enrollments = remove_udacity_accounts(enrollments)
non_udacity_engagement = remove_udacity_accounts(daily_engagement)
non_udacity_submissions = remove_udacity_accounts(project_submissions)

print (len(non_udacity_enrollments))
print (len(non_udacity_engagement))
print (len(non_udacity_submissions))
# Out:
# 1622
# 135656
# 3634

# %% [markdown]
# ## Refining the Question

# %%
#####################################
#                 6                 #
#####################################

## Create a dictionary named paid_students containing all students who either
## haven't canceled yet or who remained enrolled for more than 7 days. The keys
## should be account keys, and the values should be the date the student enrolled.
paid_students = {}
for enrollment in non_udacity_enrollments:
    if (not enrollment['is_canceled'] or
            enrollment['days_to_cancel'] > 7):
        account_key = enrollment['account_key']
        enrollment_date = enrollment['join_date']
        if (account_key not in paid_students or
                enrollment_date > paid_students[account_key]):
            paid_students[account_key] = enrollment_date
len(paid_students)
# Out:
# 995

# %% [markdown]
# ## Getting Data from First Week

# %%
# Takes a student's join date and the date of a specific engagement record,
# and returns True if that engagement record happened within one week
# of the student joining.
def within_one_week(join_date, engagement_date):
    time_delta = engagement_date - join_date
    return time_delta.days >= 0 and time_delta.days < 7

# %%
#####################################
#                 7                 #
#####################################

## Create a list of rows from the engagement table including only rows where
## the student is one of the paid students you just found, and the date is within
## one week of the student's join date.

paid_engagement_in_first_week = []
count=0
for engage in daily_engagement:
    if engage['account_key'] in paid_students:
        engagement_date=engage['utc_date']
        joint_date=paid_students[engage['account_key']]
        delta=within_one_week(joint_date,engagement_date)
        if delta is True:
            paid_engagement_in_first_week.append(engage)
        
len(paid_engagement_in_first_week)
# Out:
# 6919

# %%
paid_engagement_in_first_week
# Out:
# [OrderedDict([('utc_date', datetime.datetime(2015, 1, 9, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 11.6793745),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '0')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 10, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 37.2848873333),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '0')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 11, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 53.6337463333),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '0')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 12, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 33.4892696667),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '0')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 13, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 64.7796776667),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '0')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 14, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 151.617576833),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '0')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 15, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 142.395963833),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '0')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 6, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 9.640248),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '1')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 7, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '1')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 8, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '1')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 9, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '1')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 10, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '1')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 11, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '1')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 12, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 8.93613666667),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '1')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 6, 8, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '2')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 6, 9, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '2')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 6, 10, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '2')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 6, 11, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '2')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 6, 12, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '2')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 6, 13, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '2')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 6, 14, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '2')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 10, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '3')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 11, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '3')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 12, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '3')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 13, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '3')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 14, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '3')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 15, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '3')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 16, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '3')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 12, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '4')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 13, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '4')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 14, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '4')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 15, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 33.3214046667),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '4')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 16, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '4')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 17, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '4')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 18, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '4')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 7, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 59.7267188333),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '5')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 8, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '5')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 9, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 103.568613833),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '5')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 10, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 80.1818903333),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '5')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 11, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 36.2465346667),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '5')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 12, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 50.034099),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '5')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 13, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '5')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 6, 5, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 5.63057216667),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '6')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 6, 6, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 76.5443475),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '6')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 6, 7, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 134.276672167),
#               ('lessons_completed', 2),
#               ('projects_completed', 0),
#               ('account_key', '6')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 6, 8, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 203.849392833),
#               ('lessons_completed', 2),
#               ('projects_completed', 0),
#               ('account_key', '6')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 6, 9, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 196.479387),
#               ('lessons_completed', 2),
#               ('projects_completed', 0),
#               ('account_key', '6')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 6, 10, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 163.6741795),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '6')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 6, 11, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '6')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 12, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 42.4996946667),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '7')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 13, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '7')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 14, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 27.8152431667),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '7')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 15, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '7')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 16, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '7')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 17, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '7')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 18, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 33.8889506667),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '7')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 6, 0, 0)),
#               ('num_courses_visited', 3),
#               ('total_minutes_visited', 152.185322),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '8')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 7, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 93.6641945),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '8')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 8, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 136.103098667),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '8')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 9, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 32.9946208333),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '8')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 10, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 352.344563333),
#               ('lessons_completed', 2),
#               ('projects_completed', 0),
#               ('account_key', '8')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 11, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 184.993429333),
#               ('lessons_completed', 2),
#               ('projects_completed', 0),
#               ('account_key', '8')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 12, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 36.8284131667),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '8')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 8, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 54.8963445),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '9')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 9, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 295.804237667),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '9')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 10, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '9')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 11, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '9')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 12, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '9')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 13, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 36.2090455),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '9')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 14, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 61.5617565),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '9')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 10, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '10')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 11, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 16.2460585),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '10')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 12, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 108.982875667),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '10')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 13, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '10')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 14, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '10')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 15, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '10')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 16, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 4.89454416667),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '10')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 24, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '11')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 25, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '11')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 26, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '11')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 27, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '11')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 28, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '11')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 29, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '11')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 30, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '11')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 10, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '12')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 11, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 166.3987555),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '12')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 12, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '12')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 13, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 13.0731533333),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '12')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 14, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '12')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 15, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '12')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 16, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '12')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 1, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 79.4525436667),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '13')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 2, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 512.965277),
#               ('lessons_completed', 4),
#               ('projects_completed', 0),
#               ('account_key', '13')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 3, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 201.952520833),
#               ('lessons_completed', 3),
#               ('projects_completed', 0),
#               ('account_key', '13')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 4, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 98.1097856667),
#               ('lessons_completed', 2),
#               ('projects_completed', 0),
#               ('account_key', '13')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 5, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '13')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 6, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 47.894827),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '13')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 7, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 73.0084428333),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '13')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 6, 3, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '14')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 6, 4, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '14')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 6, 5, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 65.6221875),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '14')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 6, 6, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '14')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 6, 7, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '14')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 6, 8, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '14')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 6, 9, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '14')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 4, 0, 0)),
#               ('num_courses_visited', 4),
#               ('total_minutes_visited', 172.709897334),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '15')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 5, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 108.647330667),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '15')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 6, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 128.439285667),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '15')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 7, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '15')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 8, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '15')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 9, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 186.486383667),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '15')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 10, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 387.092143),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '15')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 13, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 86.2670026667),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '16')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 14, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '16')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 15, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '16')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 16, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 32.8532978333),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '16')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 17, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '16')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 18, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '16')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 19, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '16')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 11, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '17')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 12, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '17')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 13, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 230.602350667),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '17')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 14, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 4.89734083333),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '17')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 15, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '17')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 16, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '17')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 17, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '17')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 10, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '18')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 11, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 87.1443163333),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '18')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 12, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 33.370874),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '18')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 13, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '18')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 14, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '18')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 15, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 16.5147731667),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '18')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 16, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 18.106194),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '18')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 6, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '19')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 7, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '19')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 8, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '19')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 9, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '19')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 10, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '19')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 11, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '19')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 12, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '19')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 11, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 86.5932986667),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '20')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 12, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 253.409778),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '20')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 13, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 3.33416266667),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '20')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 14, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '20')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 15, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 77.3180143333),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '20')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 16, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 27.2837241667),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '20')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 5, 17, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '20')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 7, 17, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 333.773288166),
#               ('lessons_completed', 4),
#               ('projects_completed', 0),
#               ('account_key', '21')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 7, 18, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 2.355257),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '21')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 7, 19, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 45.3878131667),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '21')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 7, 20, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 2.50203766667),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '21')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 7, 21, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 244.166696167),
#               ('lessons_completed', 3),
#               ('projects_completed', 0),
#               ('account_key', '21')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 7, 22, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 49.3370568333),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '21')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 7, 23, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 253.581542167),
#               ('lessons_completed', 3),
#               ('projects_completed', 0),
#               ('account_key', '21')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 3, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 141.781845833),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '22')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 4, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 279.564017834),
#               ('lessons_completed', 2),
#               ('projects_completed', 0),
#               ('account_key', '22')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 5, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 64.7746043333),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '22')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 6, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 140.968281333),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '22')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 7, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 30.1164841667),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '22')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 8, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '22')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 9, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '22')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 10, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 70.513244),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '23')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 11, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 242.2342925),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '23')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 12, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 278.59787),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '23')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 13, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 385.771906167),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '23')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 14, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 111.180808333),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '23')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 15, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 417.944309),
#               ('lessons_completed', 2),
#               ('projects_completed', 0),
#               ('account_key', '23')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 16, 0, 0)),
#               ('num_courses_visited', 3),
#               ('total_minutes_visited', 85.0803843334),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '23')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 12, 3, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '24')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 12, 4, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '24')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 12, 5, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '24')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 12, 6, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '24')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 12, 7, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 217.707439667),
#               ('lessons_completed', 0),
# ...
#               ('projects_completed', 0),
#               ('account_key', '135')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 19, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '135')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 11, 20, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 18.8274783333),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '135')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 8, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '136')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 9, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '136')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 10, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '136')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 11, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '136')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 12, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '136')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 13, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '136')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 14, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 34.1685658333),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '136')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 12, 6, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 559.012065333),
#               ('lessons_completed', 3),
#               ('projects_completed', 0),
#               ('account_key', '137')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 12, 7, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 71.6231086667),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '137')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 12, 8, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '137')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 12, 9, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '137')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 12, 10, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '137')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 12, 11, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '137')]),
#  OrderedDict([('utc_date', datetime.datetime(2014, 12, 12, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 65.6123305),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '137')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 8, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '138')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 9, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '138')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 10, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '138')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 11, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '138')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 12, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '138')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 13, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 90.3995656667),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '138')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 4, 14, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '138')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 6, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '139')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 7, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '139')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 8, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '139')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 9, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '139')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 10, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '139')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 11, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 86.4587005),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '139')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 12, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '139')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 14, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 79.4930525),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '140')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 15, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 282.2645835),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '140')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 16, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 536.993184833),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '140')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 17, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 461.840850167),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '140')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 18, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 205.673807),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '140')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 19, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 403.5470465),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '140')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 1, 20, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 80.3031506667),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '140')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 7, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 144.208581333),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '141')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 8, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 325.739279333),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '141')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 9, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 7.52177466667),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '141')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 10, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 6.81155533333),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '141')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 11, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 20.0521448333),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '141')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 12, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '141')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 3, 13, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 40.6593231667),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '141')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 8, 19, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '142')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 8, 20, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '142')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 8, 21, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 180.873946167),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '142')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 8, 22, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '142')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 8, 23, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '142')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 8, 24, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 20.3442766667),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '142')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 8, 25, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '142')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 2, 9, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '143')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 2, 10, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 134.203557167),
#               ('lessons_completed', 1),
#               ('projects_completed', 0),
#               ('account_key', '143')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 2, 11, 0, 0)),
#               ('num_courses_visited', 1),
#               ('total_minutes_visited', 53.7316928333),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '143')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 2, 12, 0, 0)),
#               ('num_courses_visited', 2),
#               ('total_minutes_visited', 217.0876175),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '143')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 2, 13, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '143')]),
#  OrderedDict([('utc_date', datetime.datetime(2015, 2, 14, 0, 0)),
#               ('num_courses_visited', 0),
#               ('total_minutes_visited', 0.0),
#               ('lessons_completed', 0),
#               ('projects_completed', 0),
#               ('account_key', '143')]),
#  ...]

# %% [markdown]
# ## Exploring Student Engagement

# %%
from collections import defaultdict

# Create a dictionary of engagement grouped by student.
# The keys are account keys, and the values are lists of engagement records.
engagement_by_account = defaultdict(list)
for engagement_record in paid_engagement_in_first_week:
    account_key = engagement_record['account_key']
    engagement_by_account[account_key].append(engagement_record)

# %%
# Create a dictionary with the total minutes each student spent in the classroom during the first week.
# The keys are account keys, and the values are numbers (total minutes)
total_minutes_by_account = {}
lessons_completed_by_account={}
for account_key, engagement_for_student in engagement_by_account.items():
    total_minutes = 0
    
    for engagement_record in engagement_for_student:
        total_minutes += engagement_record['total_minutes_visited']
    total_minutes_by_account[account_key] = total_minutes
for account_key, engagement_for_student in engagement_by_account.items():
    total_minutes = 0
    
    for engagement_record in engagement_for_student:
        total_minutes += engagement_record['lessons_completed']
    lessons_completed_by_account[account_key] = total_minutes

#print(total_minutes_by_account)

# %%
import numpy as np

# Summarize the data about minutes spent in the classroom
total_minutes = list(total_minutes_by_account.values())
max_total_min=max(total_minutes)
print(max_total_min)

print ('Mean',np.mean(total_minutes))
print ('Standard deviation:', np.std(total_minutes))
print ('Minimum:', np.min(total_minutes))
print ('Maximum:', np.max(total_minutes))
# Out:
# 3564.7332644989997
# Mean 306.70832675342825
# Standard deviation: 412.99693340852957
# Minimum: 0.0
# Maximum: 3564.7332644989997

# %% [markdown]
# ## Debugging Data Analysis Code

# %%
#####################################
#                 8                 #
#####################################

## Go through a similar process as before to see if there is a problem.
## Locate at least one surprising piece of data, output it, and take a look at it.

# %% [markdown]
# ## Lessons Completed in First Week

# %%
#####################################
#                 9                 #
#####################################

def describe_data(data):
    print ('Mean', np.mean(data))
    print ('Standard deviation:', np.std(data))
    print ('Minimum:', np.min(data))
    print ('Maximum:', np.max(data))
describe_data(list(total_minutes_by_account.values()))
describe_data(list(lessons_completed_by_account.values()))
#describe_data(list(lessons_completed_by_account.values()))
## Adapt the code above to find the mean, standard deviation, minimum, and maximum for
## the number of lessons completed by each student during the first week. Try creating
## one or more functions to re-use the code above.
# Out:
# Mean 306.70832675342825
# Standard deviation: 412.99693340852957
# Minimum: 0.0
# Maximum: 3564.7332644989997
# Mean 1.636180904522613
# Standard deviation: 3.002561299829423
# Minimum: 0
# Maximum: 36

# %% [markdown]
# ## Number of Visits in First Week

# %%
######################################
#                 10                 #
######################################
def grouped_data(data,key):
    variable=defaultdict(list)
    for data_points in data:
        account_key = data_points[key]
        variable[account_key].append(data_points)
    return variable
engage_by_acc=grouped_data(paid_engagement_in_first_week,'account_key')
#print(engage_by_acc.values())
def sum_group_items(data_p,key_p):
    variable={}
    
    for account_key, datas in data_p.items():
        total = 0
    
        for data_record in datas:
            total += data_record[key_p]
        variable[account_key] = total  
    return variable
tota_min=sum_group_items(engage_by_acc,'total_minutes_visited')
less_ler=sum_group_items(engage_by_acc,'lessons_completed')


## Find the mean, standard deviation, minimum, and maximum for the number of
## days each student visits the classroom during the first week.

# %%
describe_data(list(tota_min.values()))
describe_data(list(less_ler.values()))
# Out:
# Mean 306.70832675342825
# Standard deviation: 412.99693340852957
# Minimum: 0.0
# Maximum: 3564.7332644989997
# Mean 1.636180904522613
# Standard deviation: 3.002561299829423
# Minimum: 0
# Maximum: 36

# %%
## Find the mean, standard deviation, minimum, and maximum for the number of
## days each student visits the classroom during the first week.
number_of_days={}
for account_key, datas in engage_by_acc.items():
        total = 0
    
        for data_record in datas:
            if data_record['num_courses_visited'] >=1:
                total += 1
        number_of_days[account_key] = total 
#print(number_of_days)
describe_data(list(number_of_days.values()))
# Out:
# Mean 2.8673366834170855
# Standard deviation: 2.2551980029196814
# Minimum: 0
# Maximum: 7

# %%
#paid submission
paid_submission={}
succ_submission=[]
for submissions in project_submissions:
    if (submissions['account_key'] in paid_students) and (submissions['assigned_rating'] == 'PASSED') or (submissions['assigned_rating'] == 'DISTINCTION'):
        paid_submission[submissions['account_key']]=[submissions['assigned_rating'], submissions['lesson_key']]
        
paid_submission
# Out:
# {'256': ['PASSED', '3176718735'],
#  '434': ['PASSED', '3176718735'],
#  '381': ['PASSED', '3176718735'],
#  '378': ['PASSED', '3176718735'],
#  '23': ['PASSED', '3165188753'],
#  '616': ['PASSED', '3165188753'],
#  '223': ['PASSED', '3168208620'],
#  '152': ['PASSED', '3176718735'],
#  '1098': ['PASSED', '3168208620'],
#  '273': ['PASSED', '3168208620'],
#  '599': ['PASSED', '3176718735'],
#  '639': ['PASSED', '3168208620'],
#  '324': ['PASSED', '4582204201'],
#  '439': ['PASSED', '3174288624'],
#  '608': ['PASSED', '3176718735'],
#  '30': ['PASSED', '3176718735'],
#  '168': ['PASSED', '3176718735'],
#  '224': ['PASSED', '3176718735'],
#  '575': ['PASSED', '3176718735'],
#  '641': ['PASSED', '3174288624'],
#  '156': ['DISTINCTION', '3168208620'],
#  '232': ['PASSED', '3168208620'],
#  '484': ['PASSED', '3168208620'],
#  '1224': ['PASSED', '4576183932'],
#  '1': ['PASSED', '3176718735'],
#  '611': ['PASSED', '3168208620'],
#  '189': ['PASSED', '3176718735'],
#  '491': ['PASSED', '3168208620'],
#  '535': ['PASSED', '3176718735'],
#  '57': ['PASSED', '3174288624'],
#  '61': ['PASSED', '3176718735'],
#  '375': ['PASSED', '3176718735'],
#  '130': ['PASSED', '3176718735'],
#  '365': ['PASSED', '3168208620'],
#  '90': ['PASSED', '3168208620'],
#  '694': ['PASSED', '4576183932'],
#  '84': ['PASSED', '3176718735'],
#  '618': ['PASSED', '3176718735'],
#  '497': ['PASSED', '3176718735'],
#  '605': ['PASSED', '3176718735'],
#  '313': ['PASSED', '3168208620'],
#  '537': ['PASSED', '3176718735'],
#  '581': ['PASSED', '3165188753'],
#  '629': ['PASSED', '3176718735'],
#  '541': ['PASSED', '3184238632'],
#  '207': ['PASSED', '3176718735'],
#  '416': ['PASSED', '3176718735'],
#  '612': ['PASSED', '3176718735'],
#  '258': ['PASSED', '3184238632'],
#  '413': ['PASSED', '3176718735'],
#  '652': ['PASSED', '3176718735'],
#  '412': ['PASSED', '3176718735'],
#  '647': ['PASSED', '3176718735'],
#  '474': ['PASSED', '3176718735'],
#  '150': ['PASSED', '3176718735'],
#  '138': ['PASSED', '3176718735'],
#  '198': ['PASSED', '3176718735'],
#  '309': ['PASSED', '3176718735'],
#  '984': ['PASSED', '4576183932'],
#  '601': ['PASSED', '3176718735'],
#  '606': ['PASSED', '3176718735'],
#  '230': ['PASSED', '3176718735'],
#  '632': ['PASSED', '3176718735'],
#  '83': ['PASSED', '3168208620'],
#  '195': ['PASSED', '3174288624'],
#  '69': ['PASSED', '3176718735'],
#  '361': ['PASSED', '3176718735'],
#  '533': ['PASSED', '3168208620'],
#  '321': ['PASSED', '4576183932'],
#  '7': ['PASSED', '3176718735'],
#  '523': ['PASSED', '3176718735'],
#  '501': ['PASSED', '3168208620'],
#  '68': ['PASSED', '3176718735'],
#  '517': ['PASSED', '3176718735'],
#  '544': ['PASSED', '3174288624'],
#  '250': ['PASSED', '3168208620'],
#  '314': ['PASSED', '3174288624'],
#  '318': ['PASSED', '3176718735'],
#  '415': ['PASSED', '3176718735'],
#  '645': ['PASSED', '3184238632'],
#  '427': ['PASSED', '3165188753'],
#  '311': ['DISTINCTION', '3168208620'],
#  '399': ['PASSED', '3176718735'],
#  '791': ['PASSED', '3168208620'],
#  '391': ['PASSED', '3176718735'],
#  '515': ['PASSED', '3176718735'],
#  '460': ['PASSED', '3168208620'],
#  '103': ['PASSED', '3165188753'],
#  '51': ['PASSED', '3176718735'],
#  '379': ['PASSED', '3176718735'],
#  '12': ['PASSED', '3174288624'],
#  '394': ['PASSED', '3168208620'],
#  '419': ['PASSED', '3176718735'],
#  '36': ['PASSED', '3176718735'],
#  '373': ['DISTINCTION', '3176718735'],
#  '337': ['DISTINCTION', '3176718735'],
#  '196': ['PASSED', '3176718735'],
#  '582': ['PASSED', '3176718735'],
#  '545': ['PASSED', '3176718735'],
#  '516': ['PASSED', '3176718735'],
#  '254': ['PASSED', '3168208620'],
#  '600': ['PASSED', '4576183932'],
#  '356': ['PASSED', '3168208620'],
#  '637': ['PASSED', '3176718735'],
#  '602': ['PASSED', '3176718735'],
#  '380': ['PASSED', '3168208620'],
#  '28': ['PASSED', '3168208620'],
#  '540': ['PASSED', '3168208620'],
#  '75': ['PASSED', '3176718735'],
#  '642': ['PASSED', '3165188753'],
#  '214': ['PASSED', '3176718735'],
#  '518': ['PASSED', '3176718735'],
#  '568': ['PASSED', '3165188753'],
#  '459': ['PASSED', '3168208620'],
#  '383': ['PASSED', '3168208620'],
#  '241': ['PASSED', '3176718735'],
#  '140': ['PASSED', '3165188753'],
#  '452': ['PASSED', '4576183932'],
#  '620': ['PASSED', '3176718735'],
#  '471': ['PASSED', '3168208620'],
#  '587': ['PASSED', '3176718735'],
#  '153': ['PASSED', '3176718735'],
#  '40': ['PASSED', '4582204201'],
#  '440': ['PASSED', '3176718735'],
#  '179': ['PASSED', '3165188753'],
#  '81': ['PASSED', '3174288624'],
#  '421': ['PASSED', '3165188753'],
#  '92': ['PASSED', '3168208620'],
#  '159': ['PASSED', '3176718735'],
#  '330': ['PASSED', '3176718735'],
#  '175': ['PASSED', '3168208620'],
#  '624': ['PASSED', '3176718735'],
#  '564': ['PASSED', '3176718735'],
#  '586': ['PASSED', '3176718735'],
#  '194': ['PASSED', '3176718735'],
#  '483': ['PASSED', '3176718735'],
#  '43': ['PASSED', '3176718735'],
#  '526': ['PASSED', '4582204201'],
#  '350': ['PASSED', '3168208620'],
#  '295': ['PASSED', '3176718735'],
#  '384': ['PASSED', '3176718735'],
#  '436': ['PASSED', '3165188753'],
#  '554': ['PASSED', '3176718735'],
#  '200': ['PASSED', '3176718735'],
#  '362': ['PASSED', '3176718735'],
#  '852': ['PASSED', '3168208620'],
#  '70': ['PASSED', '3176718735'],
#  '390': ['PASSED', '3168208620'],
#  '425': ['PASSED', '3174288624'],
#  '145': ['PASSED', '3174288624'],
#  '609': ['PASSED', '3176718735'],
#  '110': ['PASSED', '3176718735'],
#  '548': ['PASSED', '3176718735'],
#  '782': ['PASSED', '4576183932'],
#  '289': ['PASSED', '3176718735'],
#  '393': ['PASSED', '4576183932'],
#  '272': ['PASSED', '3174288624'],
#  '1235': ['PASSED', '4576183932'],
#  '149': ['PASSED', '3176718735'],
#  '91': ['PASSED', '3176718735'],
#  '5': ['PASSED', '3176718735'],
#  '469': ['PASSED', '3176718735'],
#  '157': ['PASSED', '3176718735'],
#  '82': ['PASSED', '3176718735'],
#  '631': ['PASSED', '3176718735'],
#  '146': ['PASSED', '3165188753'],
#  '579': ['PASSED', '3168208620'],
#  '370': ['PASSED', '3176718735'],
#  '477': ['PASSED', '3176718735'],
#  '401': ['PASSED', '3174288624'],
#  '185': ['PASSED', '3165188753'],
#  '396': ['PASSED', '3176718735'],
#  '104': ['PASSED', '3176718735'],
#  '353': ['PASSED', '3176718735'],
#  '166': ['PASSED', '3176718735'],
#  '72': ['PASSED', '3176718735'],
#  '162': ['PASSED', '3168208620'],
#  '181': ['PASSED', '3176718735'],
#  '525': ['PASSED', '3168208620'],
#  '125': ['PASSED', '3168208620'],
#  '570': ['PASSED', '3174288624'],
#  '634': ['PASSED', '3168208620'],
#  '21': ['PASSED', '4576183932'],
#  '369': ['PASSED', '3165188753'],
#  '217': ['PASSED', '3165188753'],
#  '56': ['PASSED', '3176718735'],
#  '539': ['PASSED', '3176718735'],
#  '101': ['PASSED', '3176718735'],
#  '532': ['PASSED', '3168208620'],
#  '191': ['PASSED', '3168208620'],
#  '77': ['PASSED', '3165188753'],
#  '444': ['PASSED', '3176718735'],
#  '54': ['PASSED', '3176718735'],
#  '38': ['PASSED', '3165188753'],
#  '119': ['PASSED', '3176718735'],
#  '592': ['PASSED', '3176718735'],
#  '368': ['PASSED', '3165188753'],
#  '71': ['PASSED', '4576183932'],
#  '528': ['PASSED', '3176718735'],
#  '621': ['PASSED', '3176718735'],
#  '355': ['PASSED', '3176718735'],
#  '236': ['PASSED', '3176718735'],
#  '551': ['PASSED', '3176718735'],
#  '338': ['PASSED', '3176718735'],
#  '302': ['PASSED', '3176718735'],
#  '127': ['PASSED', '3176718735'],
#  '240': ['PASSED', '3165188753'],
#  '49': ['PASSED', '3176718735'],
#  '339': ['PASSED', '3176718735'],
#  '577': ['PASSED', '3176718735'],
#  '640': ['PASSED', '3176718735'],
#  '25': ['PASSED', '3168208620'],
#  '114': ['PASSED', '3176718735'],
#  '141': ['PASSED', '3176718735'],
#  '387': ['PASSED', '3165188753'],
#  '288': ['PASSED', '3176718735'],
#  '94': ['PASSED', '3176718735'],
#  '524': ['PASSED', '3176718735'],
#  '595': ['PASSED', '3174288624'],
#  '389': ['PASSED', '3168208620'],
#  '367': ['PASSED', '3176718735'],
#  '275': ['PASSED', '3165188753'],
#  '281': ['PASSED', '3165188753'],
#  '327': ['PASSED', '3176718735'],
#  '155': ['PASSED', '3165188753'],
#  '244': ['PASSED', '3174288624'],
#  '96': ['PASSED', '3176718735'],
#  '282': ['PASSED', '3174288624'],
#  '563': ['PASSED', '3168208620'],
#  '79': ['DISTINCTION', '3168208620'],
#  '371': ['PASSED', '3176718735'],
#  '135': ['PASSED', '3168208620'],
#  '137': ['PASSED', '3176718735'],
#  '488': ['PASSED', '3168208620'],
#  '134': ['PASSED', '3176718735'],
#  '594': ['PASSED', '3176718735'],
#  '186': ['PASSED', '3168208620'],
#  '397': ['PASSED', '3165188753'],
#  '147': ['PASSED', '3176718735'],
#  '546': ['PASSED', '3168208620'],
#  '342': ['PASSED', '3176718735'],
#  '46': ['PASSED', '3176718735'],
#  '292': ['PASSED', '3165188753'],
#  '209': ['DISTINCTION', '3168208620'],
#  '613': ['PASSED', '3176718735'],
#  '193': ['PASSED', '3184238632'],
#  '346': ['PASSED', '3176718735'],
#  '347': ['PASSED', '3168208620'],
#  '97': ['PASSED', '3168208620'],
#  '93': ['PASSED', '3176718735'],
#  '357': ['PASSED', '3168208620'],
#  '628': ['PASSED', '3176718735'],
#  '418': ['PASSED', '3176718735'],
#  '508': ['PASSED', '3168208620'],
#  '521': ['PASSED', '3168208620'],
#  '66': ['PASSED', '3168208620'],
#  '142': ['PASSED', '3168208620'],
#  '486': ['PASSED', '3168208620'],
#  '108': ['PASSED', '3184238632'],
#  '58': ['PASSED', '4576183932'],
#  '100': ['PASSED', '3176718735'],
#  '510': ['PASSED', '3168208620'],
#  '32': ['PASSED', '3176718735'],
#  '197': ['PASSED', '3168208620'],
#  '0': ['PASSED', '3176718735'],
#  '511': ['PASSED', '3176718735'],
#  '467': ['PASSED', '3176718735'],
#  '171': ['PASSED', '3168208620'],
#  '561': ['PASSED', '3165188753'],
#  '352': ['PASSED', '3176718735'],
#  '239': ['PASSED', '3176718735'],
#  '89': ['PASSED', '3176718735'],
#  '251': ['PASSED', '3176718735'],
#  '143': ['PASSED', '3176718735'],
#  '136': ['PASSED', '3176718735'],
#  '190': ['PASSED', '3176718735'],
#  '283': ['PASSED', '3168208620'],
#  '31': ['PASSED', '3176718735'],
#  '229': ['PASSED', '3176718735'],
#  '500': ['PASSED', '3176718735'],
#  '60': ['PASSED', '3176718735'],
#  '530': ['PASSED', '3176718735'],
#  '506': ['PASSED', '3168208620'],
#  '308': ['PASSED', '3176718735'],
#  '453': ['PASSED', '3176718735'],
#  '131': ['PASSED', '3176718735'],
#  '245': ['PASSED', '3168208620'],
#  '126': ['PASSED', '3168208620'],
#  '364': ['PASSED', '3176718735'],
#  '457': ['PASSED', '3176718735'],
#  '409': ['PASSED', '3176718735'],
#  '20': ['PASSED', '3176718735'],
#  '132': ['PASSED', '3174288624'],
#  '715': ['PASSED', '4576183932'],
#  '340': ['PASSED', '3176718735'],
#  '205': ['PASSED', '3168208620'],
#  '37': ['PASSED', '3174288624'],
#  '47': ['PASSED', '3176718735'],
#  '259': ['PASSED', '3176718735'],
#  '490': ['PASSED', '3176718735'],
#  '113': ['PASSED', '3176718735'],
#  '42': ['PASSED', '3168208620'],
#  '6': ['PASSED', '3176718735'],
#  '172': ['PASSED', '3165188753'],
#  '139': ['PASSED', '3168208620'],
#  '372': ['PASSED', '3168208620'],
#  '395': ['PASSED', '3176718735'],
#  '392': ['PASSED', '3168208620'],
#  '464': ['PASSED', '3174288624'],
#  '242': ['PASSED', '3165188753'],
#  '117': ['PASSED', '3176718735'],
#  '445': ['PASSED', '3176718735'],
#  '426': ['PASSED', '3184238632'],
#  '341': ['PASSED', '3176718735'],
#  '183': ['PASSED', '3168208620'],
#  '304': ['PASSED', '3168208620'],
#  '784': ['PASSED', '4582204201'],
#  '437': ['PASSED', '4576183932'],
#  '291': ['PASSED', '3176718735'],
#  '86': ['PASSED', '3176718735'],
#  '158': ['PASSED', '3176718735'],
#  '76': ['PASSED', '3176718735'],
#  '358': ['PASSED', '3176718735'],
#  '388': ['PASSED', '3176718735'],
#  '597': ['PASSED', '3184238632'],
#  '78': ['PASSED', '3176718735'],
#  '751': ['PASSED', '4576183932'],
#  '1209': ['PASSED', '4576183932'],
#  '262': ['PASSED', '3176718735'],
#  '1176': ['PASSED', '4576183932'],
#  '267': ['PASSED', '3176718735'],
#  '107': ['PASSED', '3176718735'],
#  '165': ['PASSED', '3176718735'],
#  '227': ['PASSED', '3165188753'],
#  '188': ['PASSED', '3176718735'],
#  '520': ['PASSED', '3176718735'],
#  '495': ['PASSED', '3168208620'],
#  '465': ['PASSED', '3176718735'],
#  '35': ['PASSED', '3165188753'],
#  '22': ['PASSED', '3176718735'],
#  '349': ['PASSED', '3176718735'],
#  '607': ['PASSED', '3168208620'],
#  '559': ['PASSED', '4576183932'],
#  '271': ['PASSED', '4576183932'],
#  '423': ['PASSED', '3176718735'],
#  '979': ['PASSED', '4582204201'],
#  '509': ['PASSED', '3176718735'],
#  '536': ['PASSED', '3176718735'],
#  '363': ['PASSED', '3176718735'],
#  '404': ['PASSED', '3176718735'],
#  '211': ['PASSED', '3168208620'],
#  '307': ['PASSED', '3168208620'],
#  '407': ['PASSED', '3176718735'],
#  '376': ['PASSED', '4582204201'],
#  '154': ['PASSED', '3168208620'],
#  '555': ['PASSED', '3168208620'],
#  '619': ['PASSED', '3168208620'],
#  '109': ['PASSED', '3176718735'],
#  '1231': ['PASSED', '4582204201'],
#  '456': ['PASSED', '3176718735'],
#  '249': ['PASSED', '3176718735'],
#  '644': ['PASSED', '3176718735'],
#  '238': ['PASSED', '4582204201'],
#  '481': ['PASSED', '3176718735'],
#  '63': ['PASSED', '3168208620'],
#  '1087': ['PASSED', '4582204201'],
#  '646': ['PASSED', '3176718735'],
#  '216': ['PASSED', '4582204201'],
#  '124': ['PASSED', '4582204201'],
#  '199': ['PASSED', '3168208620'],
#  '128': ['PASSED', '3165188753'],
#  '542': ['PASSED', '3176718735'],
#  '503': ['PASSED', '4576183932'],
#  '451': ['PASSED', '3176718735'],
#  '492': ['PASSED', '3168208620'],
#  '485': ['PASSED', '3176718735'],
#  '556': ['PASSED', '3168208620'],
#  '13': ['PASSED', '3174288624'],
#  '651': ['PASSED', '3176718735'],
#  '320': ['PASSED', '3176718735'],
#  '4': ['PASSED', '3168208620'],
#  '220': ['PASSED', '3168208620'],
#  '269': ['PASSED', '3168208620'],
#  '410': ['PASSED', '3176718735'],
#  '593': ['PASSED', '3176718735'],
#  '578': ['PASSED', '3168208620'],
#  '226': ['PASSED', '3176718735'],
#  '8': ['PASSED', '3176718735'],
#  '454': ['PASSED', '3176718735'],
#  '928': ['PASSED', '4576183932'],
#  '498': ['PASSED', '4582204201'],
#  '133': ['PASSED', '3176718735'],
#  '398': ['PASSED', '3176718735'],
#  '161': ['PASSED', '3184238632'],
#  '29': ['PASSED', '3176718735'],
#  '213': ['PASSED', '3176718735'],
#  '326': ['PASSED', '3165188753'],
#  '438': ['PASSED', '4582204201'],
#  '812': ['PASSED', '4576183932'],
#  '332': ['PASSED', '4576183932'],
#  '325': ['PASSED', '4582204201'],
#  '924': ['PASSED', '4576183932'],
#  '446': ['PASSED', '3168208620'],
#  '234': ['PASSED', '4576183932'],
#  '617': ['PASSED', '3168208620'],
#  '507': ['PASSED', '3176718735'],
#  '235': ['PASSED', '3168208620'],
#  '513': ['PASSED', '3168208620'],
#  '626': ['PASSED', '3174288624'],
#  '296': ['PASSED', '3176718735'],
#  '99': ['PASSED', '3168208620'],
#  '203': ['PASSED', '3176718735'],
#  '643': ['PASSED', '3168208620'],
#  '650': ['PASSED', '3168208620'],
#  '560': ['PASSED', '3168208620'],
#  '222': ['PASSED', '3165188753'],
#  '163': ['PASSED', '4576183932'],
#  '328': ['DISTINCTION', '3168208620'],
#  '354': ['PASSED', '3168208620'],
#  '331': ['PASSED', '3176718735'],
#  '116': ['PASSED', '3168208620'],
#  '345': ['PASSED', '3176718735'],
#  '266': ['PASSED', '3168208620'],
#  '306': ['PASSED', '3176718735'],
#  '403': ['PASSED', '3176718735'],
#  '316': ['PASSED', '3176718735'],
#  '277': ['PASSED', '3174288624'],
#  '206': ['PASSED', '3174288624'],
#  '286': ['PASSED', '4582204201'],
#  '424': ['PASSED', '3176718735'],
#  '493': ['PASSED', '3168208620'],
#  '630': ['PASSED', '3176718735'],
#  '636': ['PASSED', '3174288624'],
#  '310': ['PASSED', '3176718735'],
#  '336': ['PASSED', '4576183932'],
#  '9': ['PASSED', '3168208620'],
#  '323': ['PASSED', '3184238632'],
#  '74': ['PASSED', '3176718735'],
#  '148': ['PASSED', '3176718735'],
#  '1143': ['PASSED', '4576183932'],
#  '473': ['PASSED', '3176718735'],
#  '400': ['PASSED', '3176718735'],
#  '102': ['PASSED', '3176718735'],
#  '53': ['PASSED', '3176718735'],
#  '121': ['PASSED', '3176718735'],
#  '557': ['PASSED', '3168208620'],
#  '184': ['PASSED', '3176718735'],
#  '287': ['PASSED', '4582204201'],
#  '278': ['PASSED', '3176718735'],
#  '204': ['PASSED', '3168208620'],
#  '80': ['PASSED', '3176718735'],
#  '843': ['PASSED', '4576183932'],
#  '422': ['PASSED', '3176718735'],
#  '420': ['PASSED', '3176718735'],
#  '514': ['PASSED', '3176718735'],
#  '435': ['PASSED', '3176718735'],
#  '429': ['PASSED', '3176718735'],
#  '479': ['PASSED', '3176718735'],
#  '990': ['PASSED', '4576183932'],
#  '487': ['PASSED', '3176718735'],
#  '940': ['PASSED', '4576183932'],
#  '562': ['PASSED', '3165188753'],
#  '202': ['DISTINCTION', '3168208620'],
#  '463': ['PASSED', '3168208620'],
#  '431': ['PASSED', '3168208620'],
#  '300': ['PASSED', '3168208620'],
#  '144': ['PASSED', '3168208620'],
#  '270': ['PASSED', '3176718735'],
#  '257': ['PASSED', '3165188753'],
#  '449': ['PASSED', '3168208620'],
#  '794': ['PASSED', '4576183932'],
#  '565': ['PASSED', '3168208620'],
#  '192': ['PASSED', '4576183932'],
#  '1058': ['PASSED', '4582204201'],
#  '633': ['PASSED', '4576183932'],
#  '333': ['PASSED', '3176718735'],
#  '45': ['DISTINCTION', '3165188753'],
#  '690': ['PASSED', '4576183932'],
#  '335': ['PASSED', '3176718735'],
#  '39': ['PASSED', '4576183932'],
#  '919': ['PASSED', '3165188753'],
#  '33': ['PASSED', '3176718735'],
#  '648': ['PASSED', '3176718735'],
#  '955': ['PASSED', '4180859007'],
#  '553': ['PASSED', '3174288624'],
#  '317': ['PASSED', '3184238632'],
#  '569': ['PASSED', '3168208620'],
#  '24': ['PASSED', '3176718735'],
#  '305': ['PASSED', '3168208620'],
#  '1014': ['PASSED', '4582204201'],
#  '170': ['PASSED', '3184238632'],
#  '649': ['PASSED', '3176718735'],
#  '265': ['PASSED', '3176718735'],
#  '428': ['PASSED', '3176718735'],
#  '450': ['PASSED', '3176718735'],
#  '15': ['PASSED', '3168208620'],
#  '417': ['PASSED', '3176718735'],
#  '494': ['PASSED', '3176718735'],
#  '348': ['PASSED', '3176718735'],
#  '169': ['PASSED', '3165188753'],
#  '218': ['PASSED', '4576183932'],
#  '301': ['PASSED', '3174288624'],
#  '447': ['PASSED', '3176718735'],
#  '574': ['PASSED', '3176718735'],
#  '343': ['PASSED', '3176718735'],
#  '111': ['PASSED', '3176718735'],
#  '201': ['PASSED', '3176718735'],
#  '531': ['PASSED', '3176718735'],
#  '552': ['PASSED', '4582204201'],
#  '414': ['PASSED', '4576183932'],
#  '73': ['PASSED', '3176718735'],
#  '1150': ['PASSED', '4576183932'],
#  '405': ['PASSED', '3176718735'],
#  '14': ['PASSED', '4582204201'],
#  '290': ['PASSED', '3176718735'],
#  '106': ['PASSED', '3165188753'],
#  '65': ['PASSED', '3176718735'],
#  '231': ['PASSED', '3168208620'],
#  '590': ['PASSED', '3176718735'],
#  '285': ['PASSED', '3176718735'],
#  '653': ['PASSED', '4582204201'],
#  '567': ['PASSED', '3176718735'],
#  '527': ['PASSED', '3176718735'],
#  '122': ['PASSED', '3176718735'],
#  '615': ['PASSED', '3176718735'],
#  '489': ['PASSED', '3168208620'],
#  '443': ['PASSED', '3165188753'],
#  '359': ['PASSED', '3168208620'],
#  '550': ['PASSED', '3176718735'],
#  '596': ['PASSED', '3168208620'],
#  '580': ['PASSED', '3174288624'],
#  '315': ['PASSED', '3168208620'],
#  '85': ['PASSED', '4110338963'],
#  '622': ['PASSED', '3165188753'],
#  '329': ['PASSED', '3176718735'],
#  '299': ['PASSED', '3176718735'],
#  '366': ['PASSED', '3176718735'],
#  '430': ['PASSED', '4576183932'],
#  '1070': ['PASSED', '4576183932'],
#  '118': ['PASSED', '3176718735'],
#  '519': ['PASSED', '3176718735'],
#  '208': ['PASSED', '3176718735'],
#  '344': ['PASSED', '3168208620'],
#  '901': ['PASSED', '4576183932'],
#  '571': ['PASSED', '3176718735'],
#  '215': ['PASSED', '3176718735'],
#  '377': ['PASSED', '3176718735'],
#  '264': ['PASSED', '3176718735'],
#  '67': ['PASSED', '3176718735'],
#  '263': ['PASSED', '3176718735'],
#  '268': ['PASSED', '3176718735'],
#  '164': ['PASSED', '3176718735'],
#  '280': ['PASSED', '3168208620'],
#  '468': ['PASSED', '3176718735'],
#  '505': ['PASSED', '3176718735'],
#  '538': ['PASSED', '4582204201'],
#  '573': ['PASSED', '3176718735'],
#  '1217': ['PASSED', '4576183932'],
#  '1131': ['PASSED', '4576183932'],
#  '499': ['PASSED', '3174288624'],
#  '62': ['PASSED', '3176718735'],
#  '11': ['PASSED', '3176718735'],
#  '212': ['PASSED', '3176718735'],
#  '167': ['PASSED', '3176718735'],
#  '351': ['PASSED', '3176718735'],
#  '233': ['PASSED', '3176718735'],
#  '210': ['PASSED', '3176718735'],
#  '858': ['PASSED', '4576183932'],
#  '625': ['PASSED', '3176718735'],
#  '50': ['PASSED', '3176718735'],
#  '386': ['PASSED', '3176718735'],
#  '589': ['PASSED', '3176718735'],
#  '177': ['PASSED', '3176718735'],
#  '466': ['PASSED', '3176718735'],
#  '27': ['PASSED', '3176718735'],
#  '588': ['PASSED', '3176718735'],
#  '1183': ['PASSED', '4576183932'],
#  '274': ['PASSED', '3176718735'],
#  '382': ['PASSED', '3176718735'],
#  '228': ['PASSED', '3176718735'],
#  '17': ['PASSED', '3176718735'],
#  '237': ['PASSED', '3176718735'],
#  '598': ['PASSED', '3168208620'],
#  '585': ['PASSED', '3168208620'],
#  '549': ['PASSED', '3176718735'],
#  '522': ['PASSED', '3168208620'],
#  '10': ['PASSED', '3176718735'],
#  '34': ['PASSED', '3176718735'],
#  '221': ['PASSED', '3176718735'],
#  '476': ['PASSED', '3176718735'],
#  '252': ['PASSED', '4582204201'],
#  '284': ['PASSED', '3176718735'],
#  '16': ['PASSED', '3176718735'],
#  '558': ['PASSED', '3168208620'],
#  '614': ['PASSED', '3165188753'],
#  '246': ['PASSED', '3176718735'],
#  '543': ['PASSED', '3176718735'],
#  '635': ['PASSED', '3176718735'],
#  '905': ['DISTINCTION', '4180859007'],
#  '334': ['PASSED', '3176718735'],
#  '129': ['PASSED', '3176718735'],
#  '219': ['PASSED', '3176718735'],
#  '176': ['PASSED', '3176718735'],
#  '973': ['PASSED', '4576183932'],
#  '885': ['PASSED', '4576183932'],
#  '950': ['PASSED', '4576183932'],
#  '297': ['PASSED', '3168208620'],
#  '3': ['PASSED', '3176718735'],
#  '115': ['PASSED', '3165188753'],
#  '160': ['PASSED', '3176718735'],
#  '502': ['PASSED', '3168208620'],
#  '583': ['PASSED', '3176718735'],
#  '319': ['PASSED', '3176718735'],
#  '182': ['PASSED', '3168208620'],
#  '475': ['PASSED', '4582204201'],
#  '504': ['PASSED', '3176718735'],
#  '461': ['PASSED', '3176718735'],
#  '279': ['PASSED', '3176718735'],
#  '112': ['PASSED', '3176718735'],
#  '255': ['PASSED', '3176718735'],
#  '572': ['PASSED', '3176718735'],
#  '298': ['PASSED', '3176718735'],
#  '462': ['PASSED', '3176718735'],
#  '1056': ['PASSED', '4576183932'],
#  '967': ['PASSED', '4582204201'],
#  '19': ['PASSED', '3168208620'],
#  '87': ['PASSED', '3176718735'],
#  '44': ['PASSED', '3176718735'],
#  '455': ['PASSED', '3176718735'],
#  '322': ['PASSED', '3176718735'],
#  '48': ['PASSED', '4582204201'],
#  '478': ['PASSED', '3176718735'],
#  '627': ['DISTINCTION', '3168208620'],
#  '374': ['PASSED', '3176718735'],
#  '276': ['PASSED', '4576183932'],
#  '225': ['PASSED', '3176718735'],
#  '442': ['PASSED', '3176718735'],
#  '441': ['PASSED', '3168208620'],
#  '303': ['PASSED', '3176718735'],
#  '64': ['PASSED', '3176718735'],
#  '433': ['PASSED', '3176718735'],
#  '798': ['PASSED', '4576183932'],
#  '576': ['PASSED', '3176718735'],
#  '432': ['PASSED', '3176718735'],
#  '260': ['PASSED', '3176718735'],
#  '480': ['PASSED', '3176718735'],
#  '742': ['PASSED', '4576183932'],
#  '98': ['PASSED', '3176718735'],
#  '458': ['PASSED', '3176718735'],
#  '385': ['PASSED', '3176718735'],
#  '408': ['PASSED', '3176718735'],
#  '402': ['PASSED', '3176718735'],
#  '187': ['PASSED', '3168208620'],
#  '180': ['PASSED', '3176718735'],
#  '603': ['PASSED', '4576183932'],
#  '566': ['PASSED', '3176718735'],
#  '294': ['PASSED', '3176718735'],
#  '534': ['PASSED', '3176718735'],
#  '105': ['PASSED', '3176718735'],
#  '512': ['PASSED', '3176718735'],
#  '610': ['PASSED', '3176718735'],
#  '496': ['PASSED', '3176718735'],
#  '472': ['DISTINCTION', '3176718735'],
#  '178': ['PASSED', '3176718735'],
#  '41': ['PASSED', '3176718735'],
#  '482': ['PASSED', '3176718735'],
#  '52': ['PASSED', '3176718735'],
#  '406': ['PASSED', '3176718735'],
#  '18': ['PASSED', '3176718735'],
#  '59': ['PASSED', '3176718735'],
#  '604': ['PASSED', '3168208620'],
#  '26': ['PASSED', '3176718735'],
#  '173': ['PASSED', '3176718735'],
#  '748': ['PASSED', '4576183932'],
#  '293': ['PASSED', '3176718735'],
#  '584': ['PASSED', '3176718735'],
#  '360': ['PASSED', '3168208620'],
#  '174': ['PASSED', '3176718735'],
#  '1216': ['PASSED', '4576183932'],
#  '591': ['PASSED', '3176718735'],
#  '261': ['PASSED', '3176718735'],
#  '88': ['PASSED', '3176718735'],
#  '883': ['PASSED', '4576183932'],
#  '151': ['DISTINCTION', '3176718735'],
#  '120': ['PASSED', '3176718735'],
#  '253': ['PASSED', '3168208620'],
#  '1000': ['PASSED', '4576183932'],
#  '55': ['PASSED', '3176718735'],
#  '529': ['PASSED', '3176718735'],
#  '1263': ['PASSED', '4576183932'],
#  '123': ['PASSED', '3176718735'],
#  '1110': ['PASSED', '4576183932'],
#  '248': ['PASSED', '3176718735'],
#  '411': ['PASSED', '3176718735'],
#  '547': ['PASSED', '3176718735'],
#  '243': ['PASSED', '3176718735'],
#  '2': ['PASSED', '3176718735'],
#  '623': ['PASSED', '3176718735'],
#  '1274': ['PASSED', '4576183932']}

# %%
## Splitting out Passing Students

# %%
######################################
#                 11                 #
######################################

## Create two lists of engagement data for paid students in the first week.
## The first list should contain data for students who eventually pass the
## subway project, and the second list should contain data for students
## who do not.

subway_project_lesson_keys = ['746169184', '3176718735']

passing_engagement = []
print(type(passing_engagement))

for  passed, key in paid_submission.items():
    print(passed)
    print(key[1])
    if (key[1] in subway_project_lesson_keys) :
            
        passing_engagement.append(passed)
    


#non_passing_engagement =
# Out:
# <class 'list'>
# 256
# 3176718735
# 434
# 3176718735
# 381
# 3176718735
# 378
# 3176718735
# 23
# 3165188753
# 616
# 3165188753
# 223
# 3168208620
# 152
# 3176718735
# 1098
# 3168208620
# 273
# 3168208620
# 599
# 3176718735
# 639
# 3168208620
# 324
# 4582204201
# 439
# 3174288624
# 608
# 3176718735
# 30
# 3176718735
# 168
# 3176718735
# 224
# 3176718735
# 575
# 3176718735
# 641
# 3174288624
# 156
# 3168208620
# 232
# 3168208620
# 484
# 3168208620
# 1224
# 4576183932
# 1
# 3176718735
# 611
# 3168208620
# 189
# 3176718735
# 491
# 3168208620
# 535
# 3176718735
# 57
# 3174288624
# 61
# 3176718735
# 375
# 3176718735
# 130
# 3176718735
# 365
# 3168208620
# 90
# 3168208620
# 694
# 4576183932
# 84
# 3176718735
# 618
# 3176718735
# 497
# 3176718735
# 605
# 3176718735
# 313
# 3168208620
# 537
# 3176718735
# 581
# 3165188753
# 629
# 3176718735
# 541
# 3184238632
# 207
# 3176718735
# 416
# 3176718735
# 612
# 3176718735
# 258
# 3184238632
# 413
# 3176718735
# 652
# 3176718735
# 412
# 3176718735
# 647
# 3176718735
# 474
# 3176718735
# 150
# 3176718735
# 138
# 3176718735
# 198
# 3176718735
# 309
# 3176718735
# 984
# 4576183932
# 601
# 3176718735
# 606
# 3176718735
# 230
# 3176718735
# 632
# 3176718735
# 83
# 3168208620
# 195
# 3174288624
# 69
# 3176718735
# 361
# 3176718735
# 533
# 3168208620
# 321
# 4576183932
# 7
# 3176718735
# 523
# 3176718735
# 501
# 3168208620
# 68
# 3176718735
# 517
# 3176718735
# 544
# 3174288624
# 250
# 3168208620
# 314
# 3174288624
# 318
# 3176718735
# 415
# 3176718735
# 645
# 3184238632
# 427
# 3165188753
# 311
# 3168208620
# 399
# 3176718735
# 791
# 3168208620
# 391
# 3176718735
# 515
# 3176718735
# 460
# 3168208620
# 103
# 3165188753
# 51
# 3176718735
# 379
# 3176718735
# 12
# 3174288624
# 394
# 3168208620
# 419
# 3176718735
# 36
# 3176718735
# 373
# 3176718735
# 337
# 3176718735
# 196
# 3176718735
# 582
# 3176718735
# 545
# 3176718735
# 516
# 3176718735
# 254
# 3168208620
# 600
# 4576183932
# 356
# 3168208620
# 637
# 3176718735
# 602
# 3176718735
# 380
# 3168208620
# 28
# 3168208620
# 540
# 3168208620
# 75
# 3176718735
# 642
# 3165188753
# 214
# 3176718735
# 518
# 3176718735
# 568
# 3165188753
# 459
# 3168208620
# 383
# 3168208620
# 241
# 3176718735
# 140
# 3165188753
# 452
# 4576183932
# 620
# 3176718735
# 471
# 3168208620
# 587
# 3176718735
# 153
# 3176718735
# 40
# 4582204201
# 440
# 3176718735
# 179
# 3165188753
# 81
# 3174288624
# 421
# 3165188753
# 92
# 3168208620
# 159
# 3176718735
# 330
# 3176718735
# 175
# 3168208620
# 624
# 3176718735
# 564
# 3176718735
# 586
# 3176718735
# 194
# 3176718735
# 483
# 3176718735
# 43
# 3176718735
# 526
# 4582204201
# 350
# 3168208620
# 295
# 3176718735
# 384
# 3176718735
# 436
# 3165188753
# 554
# 3176718735
# 200
# 3176718735
# 362
# 3176718735
# 852
# 3168208620
# 70
# 3176718735
# 390
# 3168208620
# 425
# 3174288624
# 145
# 3174288624
# 609
# 3176718735
# 110
# 3176718735
# 548
# 3176718735
# 782
# 4576183932
# 289
# 3176718735
# 393
# 4576183932
# 272
# 3174288624
# 1235
# 4576183932
# 149
# 3176718735
# 91
# 3176718735
# 5
# 3176718735
# 469
# 3176718735
# 157
# 3176718735
# 82
# 3176718735
# 631
# 3176718735
# 146
# 3165188753
# 579
# 3168208620
# 370
# 3176718735
# 477
# 3176718735
# 401
# 3174288624
# 185
# 3165188753
# 396
# 3176718735
# 104
# 3176718735
# 353
# 3176718735
# 166
# 3176718735
# 72
# 3176718735
# 162
# 3168208620
# 181
# 3176718735
# 525
# 3168208620
# 125
# 3168208620
# 570
# 3174288624
# 634
# 3168208620
# 21
# 4576183932
# 369
# 3165188753
# 217
# 3165188753
# 56
# 3176718735
# 539
# 3176718735
# 101
# 3176718735
# 532
# 3168208620
# 191
# 3168208620
# 77
# 3165188753
# 444
# 3176718735
# 54
# 3176718735
# 38
# 3165188753
# 119
# 3176718735
# 592
# 3176718735
# 368
# 3165188753
# 71
# 4576183932
# 528
# 3176718735
# 621
# 3176718735
# 355
# 3176718735
# 236
# 3176718735
# 551
# 3176718735
# 338
# 3176718735
# 302
# 3176718735
# 127
# 3176718735
# 240
# 3165188753
# 49
# 3176718735
# 339
# 3176718735
# 577
# 3176718735
# 640
# 3176718735
# 25
# 3168208620
# 114
# 3176718735
# 141
# 3176718735
# 387
# 3165188753
# 288
# 3176718735
# 94
# 3176718735
# 524
# 3176718735
# 595
# 3174288624
# 389
# 3168208620
# 367
# 3176718735
# 275
# 3165188753
# 281
# 3165188753
# 327
# 3176718735
# 155
# 3165188753
# 244
# 3174288624
# 96
# 3176718735
# 282
# 3174288624
# 563
# 3168208620
# 79
# 3168208620
# 371
# 3176718735
# 135
# 3168208620
# 137
# 3176718735
# 488
# 3168208620
# 134
# 3176718735
# 594
# 3176718735
# 186
# 3168208620
# 397
# 3165188753
# 147
# 3176718735
# 546
# 3168208620
# 342
# 3176718735
# 46
# 3176718735
# 292
# 3165188753
# 209
# 3168208620
# 613
# 3176718735
# 193
# 3184238632
# 346
# 3176718735
# 347
# 3168208620
# 97
# 3168208620
# 93
# 3176718735
# 357
# 3168208620
# 628
# 3176718735
# 418
# 3176718735
# 508
# 3168208620
# 521
# 3168208620
# 66
# 3168208620
# 142
# 3168208620
# 486
# 3168208620
# 108
# 3184238632
# 58
# 4576183932
# 100
# 3176718735
# 510
# 3168208620
# 32
# 3176718735
# 197
# 3168208620
# 0
# 3176718735
# 511
# 3176718735
# 467
# 3176718735
# 171
# 3168208620
# 561
# 3165188753
# 352
# 3176718735
# 239
# 3176718735
# 89
# 3176718735
# 251
# 3176718735
# 143
# 3176718735
# 136
# 3176718735
# 190
# 3176718735
# 283
# 3168208620
# 31
# 3176718735
# 229
# 3176718735
# 500
# 3176718735
# 60
# 3176718735
# 530
# 3176718735
# 506
# 3168208620
# 308
# 3176718735
# 453
# 3176718735
# 131
# 3176718735
# 245
# 3168208620
# 126
# 3168208620
# 364
# 3176718735
# 457
# 3176718735
# 409
# 3176718735
# 20
# 3176718735
# 132
# 3174288624
# 715
# 4576183932
# 340
# 3176718735
# 205
# 3168208620
# 37
# 3174288624
# 47
# 3176718735
# 259
# 3176718735
# 490
# 3176718735
# 113
# 3176718735
# 42
# 3168208620
# 6
# 3176718735
# 172
# 3165188753
# 139
# 3168208620
# 372
# 3168208620
# 395
# 3176718735
# 392
# 3168208620
# 464
# 3174288624
# 242
# 3165188753
# 117
# 3176718735
# 445
# 3176718735
# 426
# 3184238632
# 341
# 3176718735
# 183
# 3168208620
# 304
# 3168208620
# 784
# 4582204201
# 437
# 4576183932
# 291
# 3176718735
# 86
# 3176718735
# 158
# 3176718735
# 76
# 3176718735
# 358
# 3176718735
# 388
# 3176718735
# 597
# 3184238632
# 78
# 3176718735
# 751
# 4576183932
# 1209
# 4576183932
# 262
# 3176718735
# 1176
# 4576183932
# 267
# 3176718735
# 107
# 3176718735
# 165
# 3176718735
# 227
# 3165188753
# 188
# 3176718735
# 520
# 3176718735
# 495
# 3168208620
# 465
# 3176718735
# 35
# 3165188753
# 22
# 3176718735
# 349
# 3176718735
# 607
# 3168208620
# 559
# 4576183932
# 271
# 4576183932
# 423
# 3176718735
# 979
# 4582204201
# 509
# 3176718735
# 536
# 3176718735
# 363
# 3176718735
# 404
# 3176718735
# 211
# 3168208620
# 307
# 3168208620
# 407
# 3176718735
# 376
# 4582204201
# 154
# 3168208620
# 555
# 3168208620
# 619
# 3168208620
# 109
# 3176718735
# 1231
# 4582204201
# 456
# 3176718735
# 249
# 3176718735
# 644
# 3176718735
# 238
# 4582204201
# 481
# 3176718735
# 63
# 3168208620
# 1087
# 4582204201
# 646
# 3176718735
# 216
# 4582204201
# 124
# 4582204201
# 199
# 3168208620
# 128
# 3165188753
# 542
# 3176718735
# 503
# 4576183932
# 451
# 3176718735
# 492
# 3168208620
# 485
# 3176718735
# 556
# 3168208620
# 13
# 3174288624
# 651
# 3176718735
# 320
# 3176718735
# 4
# 3168208620
# 220
# 3168208620
# 269
# 3168208620
# 410
# 3176718735
# 593
# 3176718735
# 578
# 3168208620
# 226
# 3176718735
# 8
# 3176718735
# 454
# 3176718735
# 928
# 4576183932
# 498
# 4582204201
# 133
# 3176718735
# 398
# 3176718735
# 161
# 3184238632
# 29
# 3176718735
# 213
# 3176718735
# 326
# 3165188753
# 438
# 4582204201
# 812
# 4576183932
# 332
# 4576183932
# 325
# 4582204201
# 924
# 4576183932
# 446
# 3168208620
# 234
# 4576183932
# 617
# 3168208620
# 507
# 3176718735
# 235
# 3168208620
# 513
# 3168208620
# 626
# 3174288624
# 296
# 3176718735
# 99
# 3168208620
# 203
# 3176718735
# 643
# 3168208620
# 650
# 3168208620
# 560
# 3168208620
# 222
# 3165188753
# 163
# 4576183932
# 328
# 3168208620
# 354
# 3168208620
# 331
# 3176718735
# 116
# 3168208620
# 345
# 3176718735
# 266
# 3168208620
# 306
# 3176718735
# 403
# 3176718735
# 316
# 3176718735
# 277
# 3174288624
# 206
# 3174288624
# 286
# 4582204201
# 424
# 3176718735
# 493
# 3168208620
# 630
# 3176718735
# 636
# 3174288624
# 310
# 3176718735
# 336
# 4576183932
# 9
# 3168208620
# 323
# 3184238632
# 74
# 3176718735
# 148
# 3176718735
# 1143
# 4576183932
# 473
# 3176718735
# 400
# 3176718735
# 102
# 3176718735
# 53
# 3176718735
# 121
# 3176718735
# 557
# 3168208620
# 184
# 3176718735
# 287
# 4582204201
# 278
# 3176718735
# 204
# 3168208620
# 80
# 3176718735
# 843
# 4576183932
# 422
# 3176718735
# 420
# 3176718735
# 514
# 3176718735
# 435
# 3176718735
# 429
# 3176718735
# 479
# 3176718735
# 990
# 4576183932
# 487
# 3176718735
# 940
# 4576183932
# 562
# 3165188753
# 202
# 3168208620
# 463
# 3168208620
# 431
# 3168208620
# 300
# 3168208620
# 144
# 3168208620
# 270
# 3176718735
# 257
# 3165188753
# 449
# 3168208620
# 794
# 4576183932
# 565
# 3168208620
# 192
# 4576183932
# 1058
# 4582204201
# 633
# 4576183932
# 333
# 3176718735
# 45
# 3165188753
# 690
# 4576183932
# 335
# 3176718735
# 39
# 4576183932
# 919
# 3165188753
# 33
# 3176718735
# 648
# 3176718735
# 955
# 4180859007
# 553
# 3174288624
# 317
# 3184238632
# 569
# 3168208620
# 24
# 3176718735
# 305
# 3168208620
# 1014
# 4582204201
# 170
# 3184238632
# 649
# 3176718735
# 265
# 3176718735
# 428
# 3176718735
# 450
# 3176718735
# 15
# 3168208620
# 417
# 3176718735
# 494
# 3176718735
# 348
# 3176718735
# 169
# 3165188753
# 218
# 4576183932
# 301
# 3174288624
# 447
# 3176718735
# 574
# 3176718735
# 343
# 3176718735
# 111
# 3176718735
# 201
# 3176718735
# 531
# 3176718735
# 552
# 4582204201
# 414
# 4576183932
# 73
# 3176718735
# 1150
# 4576183932
# 405
# 3176718735
# 14
# 4582204201
# 290
# 3176718735
# 106
# 3165188753
# 65
# 3176718735
# 231
# 3168208620
# 590
# 3176718735
# 285
# 3176718735
# 653
# 4582204201
# 567
# 3176718735
# 527
# 3176718735
# 122
# 3176718735
# 615
# 3176718735
# 489
# 3168208620
# 443
# 3165188753
# 359
# 3168208620
# 550
# 3176718735
# 596
# 3168208620
# 580
# 3174288624
# 315
# 3168208620
# 85
# 4110338963
# 622
# 3165188753
# 329
# 3176718735
# 299
# 3176718735
# 366
# 3176718735
# 430
# 4576183932
# 1070
# 4576183932
# 118
# 3176718735
# 519
# 3176718735
# 208
# 3176718735
# 344
# 3168208620
# 901
# 4576183932
# 571
# 3176718735
# 215
# 3176718735
# 377
# 3176718735
# 264
# 3176718735
# 67
# 3176718735
# 263
# 3176718735
# 268
# 3176718735
# 164
# 3176718735
# 280
# 3168208620
# 468
# 3176718735
# 505
# 3176718735
# 538
# 4582204201
# 573
# 3176718735
# 1217
# 4576183932
# 1131
# 4576183932
# 499
# 3174288624
# 62
# 3176718735
# 11
# 3176718735
# 212
# 3176718735
# 167
# 3176718735
# 351
# 3176718735
# 233
# 3176718735
# 210
# 3176718735
# 858
# 4576183932
# 625
# 3176718735
# 50
# 3176718735
# 386
# 3176718735
# 589
# 3176718735
# 177
# 3176718735
# 466
# 3176718735
# 27
# 3176718735
# 588
# 3176718735
# 1183
# 4576183932
# 274
# 3176718735
# 382
# 3176718735
# 228
# 3176718735
# 17
# 3176718735
# 237
# 3176718735
# 598
# 3168208620
# 585
# 3168208620
# 549
# 3176718735
# 522
# 3168208620
# 10
# 3176718735
# 34
# 3176718735
# 221
# 3176718735
# 476
# 3176718735
# 252
# 4582204201
# 284
# 3176718735
# 16
# 3176718735
# 558
# 3168208620
# 614
# 3165188753
# 246
# 3176718735
# 543
# 3176718735
# 635
# 3176718735
# 905
# 4180859007
# 334
# 3176718735
# 129
# 3176718735
# 219
# 3176718735
# 176
# 3176718735
# 973
# 4576183932
# 885
# 4576183932
# 950
# 4576183932
# 297
# 3168208620
# 3
# 3176718735
# 115
# 3165188753
# 160
# 3176718735
# 502
# 3168208620
# 583
# 3176718735
# 319
# 3176718735
# 182
# 3168208620
# 475
# 4582204201
# 504
# 3176718735
# 461
# 3176718735
# 279
# 3176718735
# 112
# 3176718735
# 255
# 3176718735
# 572
# 3176718735
# 298
# 3176718735
# 462
# 3176718735
# 1056
# 4576183932
# 967
# 4582204201
# 19
# 3168208620
# 87
# 3176718735
# 44
# 3176718735
# 455
# 3176718735
# 322
# 3176718735
# 48
# 4582204201
# 478
# 3176718735
# 627
# 3168208620
# 374
# 3176718735
# 276
# 4576183932
# 225
# 3176718735
# 442
# 3176718735
# 441
# 3168208620
# 303
# 3176718735
# 64
# 3176718735
# 433
# 3176718735
# 798
# 4576183932
# 576
# 3176718735
# 432
# 3176718735
# 260
# 3176718735
# 480
# 3176718735
# 742
# 4576183932
# 98
# 3176718735
# 458
# 3176718735
# 385
# 3176718735
# 408
# 3176718735
# 402
# 3176718735
# 187
# 3168208620
# 180
# 3176718735
# 603
# 4576183932
# 566
# 3176718735
# 294
# 3176718735
# 534
# 3176718735
# 105
# 3176718735
# 512
# 3176718735
# 610
# 3176718735
# 496
# 3176718735
# 472
# 3176718735
# 178
# 3176718735
# 41
# 3176718735
# 482
# 3176718735
# 52
# 3176718735
# 406
# 3176718735
# 18
# 3176718735
# 59
# 3176718735
# 604
# 3168208620
# 26
# 3176718735
# 173
# 3176718735
# 748
# 4576183932
# 293
# 3176718735
# 584
# 3176718735
# 360
# 3168208620
# 174
# 3176718735
# 1216
# 4576183932
# 591
# 3176718735
# 261
# 3176718735
# 88
# 3176718735
# 883
# 4576183932
# 151
# 3176718735
# 120
# 3176718735
# 253
# 3168208620
# 1000
# 4576183932
# 55
# 3176718735
# 529
# 3176718735
# 1263
# 4576183932
# 123
# 3176718735
# 1110
# 4576183932
# 248
# 3176718735
# 411
# 3176718735
# 547
# 3176718735
# 243
# 3176718735
# 2
# 3176718735
# 623
# 3176718735
# 1274
# 4576183932

# %%
print(len(passing_engagement))
# Out:
# 394

# %% [markdown]
# ## Comparing the Two Student Groups

# %%
######################################
#                 12                 #
######################################

## Compute some metrics you're interested in and see how they differ for
## students who pass the subway project vs. students who don't. A good
## starting point would be the metrics we looked at earlier (minutes spent
## in the classroom, lessons completed, and days visited).

# %% [markdown]
# ## Making Histograms

# %%
######################################
#                 13                 #
######################################

## Make histograms of the three metrics we looked at earlier for both
## students who passed the subway project and students who didn't. You
## might also want to make histograms of any other metrics you examined.

# %% [markdown]
# ## Improving Plots and Sharing Findings

# %%
######################################
#                 14                 #
######################################

## Make a more polished version of at least one of your visualizations
## from earlier. Try importing the seaborn library to make the visualization
## look better, adding axis labels and a title, and changing one or more
## arguments to the hist() function.
